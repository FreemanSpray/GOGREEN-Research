# %% [markdown]
# This is normal text

# %% [markdown]
# # header 1
# ## header 2
# ### header 3
# #### header 4
# *italics*
#
# **Bold**
#
# This is a list
# * item 1
# * item 2
# * item 3
#
# This is an enumerated list
# 1. item a
# 2. item b
# 3. item c

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.arange(0,100)
y = 2 * np.arange(0,100)
z = np.arange(0,50,0.5)
#display(x)
#display(y)
#display(z)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('test.png')

# %% [markdown]
# This is a caption for the plot.  Always put captions for your plots
