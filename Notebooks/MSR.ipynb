# %%
import warnings

with warnings.catch_warnings(): #suppressing depracation warnings for the import and instantion process for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)

    # Import
    # %run "C:/Users/panda/Documents/Github/GOGREEN-Research/Code/GOGREEN.py"

    # Instantiate
    gg = GOGREEN( 'C:/Users/panda/Desktop/GOGREEN_Working/')

# %%
searchCriteria = [
    'Star == 0',
    'K_flag == 0',
    'totmask == 0',
    're > 0',
    'Fit_flag > 1',
    'n < 6',
    'HSTFOV_flag == 1'
]
gg.standardCriteria = searchCriteria

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 2, useLog=[True,True], colorType='membership', xRange = [7.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all cluster galaxies (spectroscopic vs photometric z) - separate plots

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useLog=[True,True], colorType='membership', xRange = [7.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all cluster galaxies (spectroscopic vs photometric z) - combined plot

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 2, useLog=[True,True], colorType='passive', xRange = [9.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all cluster galaxies (quiescent vs star forming) - separate plots

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useLog=[True,True], colorType='passive', xRange = [9.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all cluster galaxies (quiescent vs star forming) - combined plot

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    # Create a table of the data presented above in a designated output file
    gg.makeTable('C:/Users/panda/Documents/Github/GOGREEN-Research/Notebooks/output.txt')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useLog=[True,True], useMembers='not', colorType='membership', xRange = [7.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\astropy\units\quantity.py:1527, in Quantity._to_own_unit(self, value, check_precision)
#    1526 try:
# -> 1527     _value = value.to_value(self.unit)
#    1528 except AttributeError:
#    1529     # We're not a Quantity.
#    1530     # First remove two special cases (with a fast test):
#    1531     # 1) Maybe masked printing? MaskedArray with quantities does not
#    1532     # work very well, but no reason to break even repr and str.
#    1533     # 2) np.ma.masked? useful if we're a MaskedQuantity.
#
# AttributeError: 'int' object has no attribute 'to_value'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# ...

# %% [markdown]
# MSR for all field galaxies (spectroscopic vs photometric z)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useLog=[True,True], useMembers='not', colorType='passive', colors=['red','blue'], xRange = [9.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all field galaxies (quiescent vs star forming)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 2, useLog=[True,True], colorType='sersic', xRange = [7.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all cluster galaxies (2.5 < n < 6 vs n < 2.5) - separate plots

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useLog=[True,True], colorType='sersic', xRange = [7.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %% [markdown]
# MSR for all cluster galaxies (2.5 < n < 6 vs n < 2.5) - combined plot

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    ratios = gg.getRatio(x=10.5)
    print(ratios)
# Out:
# [1.0753567997581255, 1.0299666415566193]

# %% [markdown]
# The two values above are ratios of the MSR of galaxies in the cluster over the MSR of galaxies in the field at Mstellar = 10.5. The first value is quiescent only, the second value is star-forming only.

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.getRatio(x=10.5, plotLines=True, xRange = [7.5, 11.5], yRange = [-1.5, 1.5])

# %% [markdown]
# The median size of quiescent vs star-forming x member vs non member galaxies in 3 mass bins (10^8 Msun < Mstar < 10^9 Msun, 10^9 Msun < Mstar < 10^10 Msun, 10^10 Msun < Mstar < 10^11 Msun)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.getMedian()

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 2, useLog=[True,True], xRange = [7.5, 11.5], yRange = [-1.5, 1.5], xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 'zphot', 3, useLog=[True,False], colorType='passive', xLabel='log(Mstellar)', yLabel='zphot')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 'zphot', 3, useLog=[True,False], useMembers='not', colorType='passive', xLabel='log(Mstellar)', yLabel='zphot')

# %%
searchCriteria = [
    'Star == 0',
    'K_flag == 0',
    'totmask == 0',
    're > 0',
    'Fit_flag > 1',
    'n < 6',
    'HSTFOV_flag == 1',
    '1 < zphot < 1.5'
]
gg.standardCriteria = searchCriteria

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 'zphot', 3, useLog=[True,False], colorType='passive', xLabel='log(Mstellar)', yLabel='zphot')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 'zphot', 3, useLog=[True,False], useMembers='not', colorType='passive', xLabel='log(Mstellar)', yLabel='zphot')

# %%
searchCriteria = [
    'Star == 0',
    'K_flag == 0',
    'totmask == 0',
    're > 0',
    'Fit_flag > 1',
    'n < 6',
    'HSTFOV_flag == 1',
    '1 < zphot < 1.5',
    '1 < zspec < 1.5'
]
gg.standardCriteria = searchCriteria

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 'zphot', 3, useLog=[True,False], colorType='passive', xLabel='log(Mstellar)', yLabel='zphot')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 'zphot', 3, useLog=[True,False], useMembers='not', colorType='passive', xLabel='log(Mstellar)', yLabel='zphot')
