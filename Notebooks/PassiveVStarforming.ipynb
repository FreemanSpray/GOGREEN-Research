# %%
# Import
# %run "C:/Users/panda/Documents/Github/GOGREEN-Research/Code/GOGREEN.py"

# Instantiate
gg = GOGREEN( 'C:/Users/panda/Desktop/GOGREEN_Working/')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._galfitCatalog = self._galfitCatalog.append(galfitClusterDF)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._matchedCatalog = self._matchedCatalog.append(matchedClusterDF)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._galfitCatalog = self._galfitCatalog.append(galfitClusterDF)
# ...

# %%
searchCriteria = [
    'Star == 0',
    'K_flag == 0',
    'totmask == 0',
    're > 0',
    'Fit_flag > 1',
    'n < 6',
    'HSTFOV_flag == 1'
]
gg.standardCriteria = searchCriteria

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SPT0205', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SPT0546', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SPT2106', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0035', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0219', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0335', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0035', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1033', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1034', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1051', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1616', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1634', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1638', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0034', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0036', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS0215', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1047', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SpARCS1613', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SXDF49', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SXDF64', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SXDF76', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SXDF76b', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='SXDF87', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='COSMOS-125', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='COSMOS-221', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='COSMOS-28', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='VMINJ', yQuantityName='UMINV', plotType=1, clusterName='COSMOS-63', colorType='passive', xLabel='V - J', yLabel='U - V')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
