# %%
import warnings
import pandas as pd
import numpy as np
    
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

with warnings.catch_warnings(): #suppressing depracation warnings for the import and instantion process for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)

    # Import
    # %run "C:/Users/panda/Documents/Github/GOGREEN-Research/Code/GOGREEN_REFACTORED.py"

    # Instantiate
    gg = GOGREEN( 'C:/Users/panda/Desktop/GOGREEN_Working/')
    
    #print(gg.catalog.columns.to_list())

# %%
searchCriteria = [
            'Star == 0',
            'K_flag == 0',
            'totmask == 0',
            're > 0',
            'Mstellar > 6300000000',
            'Fit_flag > 1',
            'n < 6',
            'HSTFOV_flag == 1',
            '(1 < zspec < 1.5) or ((Redshift_Quality != 3) and (Redshift_Quality != 4) and (1 < zphot < 1.5))'
]
gg.standardCriteria = searchCriteria

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 2, useLog=[True,True], colorType='membership', xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='passive', xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True, plotErrBars=True)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='not', useLog=[True,True], colorType='passive', xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True, plotErrBars=True)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    ratios = gg.getRatio(x=10.5)
    print(ratios)
# Out:
# [0.9014247217573074, 1.0702920435814525]

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    ratios = gg.getRatio(x=10.5, bootstrap=False)
    print(ratios)
# Out:
# [0.9014247217573074, 1.0702920435814525]

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='GV', xLabel='log(Mstellar)', yLabel='log(Re)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\computation\scope.py:195, in Scope.resolve(self, key, is_local)
#     194 if self.has_resolvers:
# --> 195     return self.resolvers[key]
#     197 # if we're here that means that we have no locals and we also have
#     198 # no resolvers
#
# File ~\anaconda3\lib\collections\__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File ~\anaconda3\lib\collections\__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'NUVMINV'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='BQ', xLabel='log(Mstellar)', yLabel='log(Re)')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='PSB', xLabel='log(Mstellar)', yLabel='log(Re)')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for the import and instantion process for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    # Test
    gg.testPlots()
# Out:
# test passed.
