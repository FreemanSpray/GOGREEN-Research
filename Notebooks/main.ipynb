# %%
import warnings

with warnings.catch_warnings(): #suppressing depracation warnings for the import and instantion process for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)

    # Import
    # %run "C:/Users/panda/Documents/Github/GOGREEN-Research/Code/GOGREEN_REFACTORED.py"

    # Instantiate
    gg = GOGREEN( 'C:/Users/panda/Desktop/GOGREEN_Working/')

# %%
searchCriteria = [
            'Star == 0',
            'K_flag == 0',
            'totmask == 0',
            're > 0',
            'Mstellar > 6300000000',
            'Fit_flag > 1',
            'n < 6',
            'HSTFOV_flag == 1',
            '(1 < zspec < 1.5) or ((Redshift_Quality != 3) and (Redshift_Quality != 4) and (1 < zphot < 1.5))'
]
gg.standardCriteria = searchCriteria

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 2, useLog=[True,True], colorType='membership', xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='passive', xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='not', useLog=[True,True], colorType='passive', xLabel='log(Mstellar)', yLabel='log(Re)', fitLine=True)

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    ratios = gg.getRatio(x=10.5)
    print(ratios)
# Out:
# [0.6349907642800361, 1.4261906547097407]

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='GV', xLabel='log(Mstellar)', yLabel='log(Re)')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='BQ', xLabel='log(Mstellar)', yLabel='log(Re)')

# %%
with warnings.catch_warnings(): #suppressing depracation warnings for readability purposes
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)
    
    gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='PSB', xLabel='log(Mstellar)', yLabel='log(Re)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cPHOTID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       2 warnings.simplefilter("ignore")
#       3 warnings.warn("deprecated", DeprecationWarning)
# ----> 5 gg.plot('Mstellar', 're', 3, useMembers='only', useLog=[True,True], colorType='PSB', xLabel='log(Mstellar)', yLabel='log(Re)')
#
# File ~\Documents\GitHub\GOGREEN-Research\Code\GOGREEN_REFACTORED.py:1264, in GOGREEN.plot(self, xQuantityName, yQuantityName, plotType, clusterName, additionalCriteria, useMembers, colorType, colors, useStandards, xRange, yRange, xLabel, yLabel, useLog, fitLine)
#    1262 # Plot depending on how the values should be colored (hold off on MSR fit lines since this needs to be handled separately for plotType 3)
#    1263 if (clusterName != self._structClusterNames[-1]):
# -> 1264     x, y = self.plotUnwrapped(xQuantityName, yQuantityName, additionalCriteria, colorType, useStandards, useLog, False, data, color1, color2, plt, axes=None, row=None, col=None, holdLbls=True)
#    1265 # Only add legend labels for the last plot otherwise the lengend will be filled with multiple duplicates of these labels
#    1266 else:
#    1267     x, y = self.plotUnwrapped(xQuantityName, yQuantityName, additionalCriteria, colorType, useStandards, useLog, False, data, color1, color2, plt, axes=None, row=None, col=None, holdLbls=False)
#
# File ~\Documents\GitHub\GOGREEN-Research\Code\GOGREEN_REFACTORED.py:1011, in GOGREEN.plotUnwrapped(self, xQuantityName, yQuantityName, additionalCriteria, colorType, useStandards, useLog, fitLine, data, color1, color2, plot, axes, row, col, holdLbls)
#    1008     bLbl = 'Other'
#    1009 elif colorType == 'PSB':
#    1010     # We need to query the redshift catalogue instead of the structural catalogue, as this is the catalogue with d4000 and delta_BIC values]
# -> 1011     redshiftData = self.convertData(data, self._redshiftCatalog)
#    1012     # Build gv query string (from McNab et al 2021)
#    1013     psbQuery = 'd4000 < 1.45 and delta_BIC < -10' # (D4000 < 1.45) ∩ (ΔBIC < −10)
#
# File ~\Documents\GitHub\GOGREEN-Research\Code\GOGREEN_REFACTORED.py:216, in GOGREEN.convertData(self, source, target)
#     215 def convertData(self, source:pd.DataFile, target:pd.DataFile) -> pd.DataFrame:
# --> 216     ret = target[target['cPHOTID'].isin(source['cPHOTID'])]
#     217     return ret
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'cPHOTID'
