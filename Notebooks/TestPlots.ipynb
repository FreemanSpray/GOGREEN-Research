# %%
# Import
# %run "C:/Users/panda/Documents/Github/GOGREEN-Research/Code/GOGREEN.py"

# Instantiate
gg = GOGREEN( 'C:/Users/panda/Desktop/GOGREEN_Working/')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._galfitCatalog = self._galfitCatalog.append(galfitClusterDF)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._matchedCatalog = self._matchedCatalog.append(matchedClusterDF)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._galfitCatalog = self._galfitCatalog.append(galfitClusterDF)
# ...

# %%
gg.catalog
# Out:
#            Cluster    cPHOTID  SPECID          ra        dec  zspec  \
# 0          SPT0205  101000254      -1   31.576448 -58.548923    NaN
# 1          SPT0205  101000272      -1   31.449797 -58.548134    NaN
# 2          SPT0205  101000286      -1   31.382263 -58.548920    NaN
# 3          SPT0205  101000290      -1   31.419193 -58.548588    NaN
# 4          SPT0205  101000293      -1   31.528271 -58.548615    NaN
# ...            ...        ...     ...         ...        ...    ...
# 274987  SpARCS1613  219005807      -1  243.386673  56.895893    NaN
# 274988  SpARCS1613  219005808      -1  243.300598  56.903133    NaN
# 274989  SpARCS1613  219005809      -1  243.459473  56.902355    NaN
# 274990  SpARCS1613  219005810      -1  243.164047  56.906891    NaN
# 274991  SpARCS1613  219005811      -1  243.487106  56.903622    NaN
#
#         Redshift_Quality   zphot  zphot_l68  zphot_u68  ...     n  n_err  \
# 0                    NaN  0.6916      0.653      0.735  ... -99.0  -99.0
# ...

# %%
help(gg.plot)
# Out:
# Help on method plot in module __main__:
#
# plot(xQuantityName: str, yQuantityName: str, plotType: int, clusterName: str = None, additionalCriteria: list = None, onlyMembers: bool = True, colorType: str = None, colors: list = None, useStandards: bool = True, xRange: list = None, yRange: list = None, xLabel: str = '', yLabel: str = '', useLog: list = [False, False], fitLine: bool = False, fitX: str = None, fitY: str = None) method of __main__.GOGREEN instance
#     plot Generates a plot(s) of param:xQuantityName vs param:yQuantityName according to param:plotType
#
#     :param xQuantityName:      Name of the column whose values are to be used as the x
#     :param yQuantityName:      Name of the column whose values are to be used as the y
#     :param plotType:           How to plots should be generated
#                                 Value: 1 - plot only the cluster provided in param:clusterName
# ...

# %%
gg.catalog.columns
# Out:
# Index(['Cluster', 'cPHOTID', 'SPECID', 'ra', 'dec', 'zspec',
#        'Redshift_Quality', 'zphot', 'zphot_l68', 'zphot_u68', 'UMINV', 'VMINJ',
#        'Star', 'K_flag', 'totmask', 'Mstellar', 'u_tot', 'g_tot', 'r_tot',
#        'i_tot', 'z_tot', 'y_tot', 'V_tot', 'B_tot', 'J_tot', 'H_tot', 'K_tot',
#        'Ks_tot', 'IRAC1_tot', 'IRAC2_tot', 'IRAC3_tot', 'IRAC4_tot',
#        'IA484_tot', 'IA527_tot', 'IA624_tot', 'IA679_tot', 'IA738_tot',
#        'IA767_tot', 'IB427_tot', 'IB464_tot', 'IB505_tot', 'IB574_tot',
#        'IB709_tot', 'IB827_tot', 'fuv_tot', 'nuv_tot', 'mips24_tot', 'eu_tot',
#        'eg_tot', 'er_tot', 'ei_tot', 'ez_tot', 'ey_tot', 'eV_tot', 'eB_tot',
#        'eJ_tot', 'eH_tot', 'eK_tot', 'eKs_tot', 'eIRAC1_tot', 'eIRAC2_tot',
#        'eIRAC3_tot', 'eIRAC4_tot', 'eIA484_tot', 'eIA527_tot', 'eIA624_tot',
#        'eIA679_tot', 'eIA738_tot', 'eIA767_tot', 'eIB427_tot', 'eIB464_tot',
#        'eIB505_tot', 'eIB574_tot', 'eIB709_tot', 'eIB827_tot', 'efuv_tot',
# ...

# %%
searchCriteria = [
    'Star == 0',
    'K_flag == 0',
    'totmask == 0',
    're > 0',
    'Fit_flag > 1',
    'n < 6',
    'HSTFOV_flag == 1'
]
gg.standardCriteria = searchCriteria

# %%
gg.plot(xQuantityName='Mstellar', yQuantityName='re', plotType=1, clusterName='SPT2106', useLog=[True,True], colorType='membership', xLabel='log(Mstellar)', yLabel='Effective Radius(arcsec)')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)

# %%
gg.plot(xQuantityName='Mstellar', yQuantityName='re', plotType=2, useLog=[True,True], colorType='membership', xLabel='log(Mstellar)', yLabel='Effective Radius(arcsec)')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
gg.plot(xQuantityName='Mstellar', yQuantityName='re', plotType=3, useLog=[True,True], colorType='membership', xLabel='log(Mstellar)', yLabel='Effective Radius(arcsec)')
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
gg.plot(xQuantityName='Mstellar', yQuantityName='re', plotType=1, clusterName='SPT2106', useLog=[True,True], xLabel='log(Mstellar)', yLabel='Effective Radius(arcsec)', fitLine=True)
# Out:
# C:\Users\panda\Documents\GitHub\GOGREEN-Research\Code\GOGREEN.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   memberGalaxies = specZgalaxies.append(photZgalaxies)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
